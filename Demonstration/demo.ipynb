# %% [markdown]
# # Demonstration of the end-to-end pipeline for the AI Marketing planning tool.

# %% [markdown]
# ### 1. Fetch Data from the desired platforms

# %%
from get_data import fetch_from_twitter

# %%
competitor_names = ['AldiUK', 'Tesco']

# %%
for competitor_name in competitor_names:
    fetch_from_twitter(competitor_name, MAX_TWEETS=1000)
# Out:
# Fetching tweets from AldiUK...
# Fetching tweets from AldiUK...Done
# Fetching tweets from Tesco...
# Fetching tweets from Tesco...Done

# %% [markdown]
# ### 2. Preprocess the data

# %% [markdown]
# #### 2.1. Integrate all the data files into a single .csv file

# %%
# !python data_integrator.py

# %% [markdown]
# #### 2.2. Clean the data

# %%
# !python data_cleaner.py

# %% [markdown]
# ### 3. Analyze the data for insights

# %%
from similarity_analysis import competitor_competitor_similarity
from keyword_analysis import get_keywords

# %% [markdown]
# #### 3.1 Find competitor-competitor similarity

# %%
competitor_competitor_similarity()
# Out:
# Finding similarity between the competitor 1 aldiuk  and the competitor 2 tesco ...

# %% [markdown]
# #### 3.2 Get keywords for all the competitors.

# %%
competitor_competitor_similarity()
# Out:
# Finding similarity between the competitor 1 aldiuk  and the competitor 2 tesco ...

# %% [markdown]
# #### 3.2 Get keywords for all the competitors.

# %%
get_keywords()
# Out:
# Getting keywords for the competitor: aldiuk
# Getting keywords for the competitor: tesco

# %% [markdown]
# ### 4. Visualize the results

# %%
from heatmap_viz import show_heatmap
from wordcloud_viz import show_wordcloud

# %% [markdown]
# #### 4.1. Heatmap visualization

# %%
show_heatmap(comp_comp=True)

# %% [markdown]
# #### 4.2. Wordcloud visualization

# %%
show_wordcloud(comp=True, comp_name='aldiuk')

# %%
show_wordcloud(comp=True, comp_name='tesco')

# %% [markdown]
# ### Backfill 2020-09-30
# - Focus: **Influencer**
# - Document market insights for Influencer

# %% [markdown]
# ### Backfill 2020-11-03
# - Focus: **NLP**
# - Document market insights for NLP

# %% [markdown]
# ### Backfill 2020-12-30
# - Focus: **Marketing**
# - Add visualization for Marketing
